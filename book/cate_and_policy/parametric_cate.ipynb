# %% [markdown]
# # CATE with OLS
#
# 그냥 Treatment랑 공변량의 interaction을 넣으면 그 계수가 CATE 추정치가 됩니다.

# %% [markdown]
# ### 질문이나 의견을 남겨주세요.
# <script src="https://utteranc.es/client.js"
#         repo="CausalInferenceLab/awesome-causal-inference-python"
#         issue-term="pathname"
#         theme="github-light"
#         crossorigin="anonymous"
#         async>
# </script>
